# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import numpy as np
import pandas as pd
import scipy
import matplotlib.pyplot as plt

import re

from tqdm import tqdm

# %%
np.__version__, pd.__version__
# Out:
# ('2.3.2', '2.3.2')

# %%
plt.style.use('ggplot')

# %%
# with open("data_1.csv", "r", errors="replace") as f:
#     head = [next(f) for _ in range(5)]
# print(head)

# %%
d1 = pd.read_csv('data_1.csv')
d1.head()
# Out:
#   Q3a Q3b Q4 Q5 Q6 Q12 Q13 Q14 Q15 Q16  ... Q54 Q54x Q55 Q56_1 Q56_2 Q56_3  \
# 0   3   6  3  3  3   3   4   2   1   2  ...   1    3   2
# 1   1   6  1  3  1   2   5   4   4   3  ...   2    1   7     1
# 2   6      1  1  1   2   4   2   1   2  ...   1    3   4
# 3   2   6  2  2  2   4   2   1   3   1  ...   2    2   1     1
# 4   1   5  1  1  1   2   4   2   1   2  ...   2    2   4
#
#   Q56_4 Q56_5 Q56_6 Q56_7
# 0     1
# 1
# 2                       1
# 3
# 4                       1
#
# [5 rows x 121 columns]

# %% [markdown]
# ### Exploratory Data Analysis & Wrangling

# %%
d1.shape
# Out:
# (8199, 121)

# %%
d1 = d1.replace(' ', float('nan'))
d1.head(1)
# Out:
#   Q3a Q3b Q4 Q5 Q6 Q12 Q13 Q14 Q15 Q16  ... Q54 Q54x Q55 Q56_1 Q56_2 Q56_3  \
# 0   3   6  3  3  3   3   4   2   1   2  ...   1    3   2   NaN   NaN   NaN
#
#   Q56_4 Q56_5 Q56_6 Q56_7
# 0     1   NaN   NaN   NaN
#
# [1 rows x 121 columns]

# %%
d1.columns.values
# Out:
# array(['Q3a', 'Q3b', 'Q4', 'Q5', 'Q6', 'Q12', 'Q13', 'Q14', 'Q15', 'Q16',
#        'Q17', 'Q20', 'Q21', 'Q22', 'Q23', 'Q24', 'Q25', 'Q26a', 'Q26b_1',
#        'Q26b_2', 'Q26b_3', 'Q26b_4', 'Q26b_5', 'AD', 'AGE', 'CD', 'CNTY',
#        'CompletionDate', 'F12', 'F13', 'F14', 'F15', 'F16', 'F17', 'F18',
#        'F19', 'F20', 'lang', 'latlang', 'likely', 'pid3', 'region',
#        'region_coarse', 'RZIP', 'RZIP4', 'SD', 'SEX', 'URBANICITY', 'Q40',
#        'Q41', 'Q42', 'Q43_1', 'Q43_2', 'Q43_3', 'Q43_4', 'Q43_5', 'Q43_6',
#        'Q43_7', 'Q44', 'Q45', 'Q46', 'Q47_argentina', 'Q47_bolivia',
#        'Q47_chile', 'Q47_colombia', 'Q47_costa_rica', 'Q47_cuba',
#        'Q47_ecuador', 'Q47_el_salvador', 'Q47_guatemala', 'Q47_honduras',
#        'Q47_mexico', 'Q47_nicaragua', 'Q47_others', 'Q47_panama',
#        'Q47_paraguay', 'Q47_peru', 'Q47_puerto_rico', 'Q47_uruguay',
#        'Q47_venezuela', 'Q48_bangladesh', 'Q48_bhutan', 'Q48_burma',
# ...

# %%
var = 'Q12' # The variable we want to measure using MRP

# %%
### FOR Q12
if var == 'Q12':
    d1['Q12'] = d1['Q12'].replace({
        '1':0,
        '2':0,
        '3':1,
        '4':1
    }) # 0 = Approve, 1 = Disapprove

# %%
d1[var].value_counts(normalize=True)
# Out:
# Q12
# 1    0.491397
# 0    0.486150
# 5    0.022453
# Name: proportion, dtype: float64

# %%
poststrat_vars = ['AGE', 'CNTY',
        'pid3', 'SEX', 'Q42', 'Q43_1', 'Q43_2', 'Q43_3', 'Q43_4', 'Q43_5', 'Q43_6',
       'Q43_7', 'Q49', 'Q52', 'Q53', 'Q54x', 'Q55', 'region']

# %%
d1['CNTY'].value_counts(normalize=True)
# Out:
# CNTY
# 19    0.216490
# 37    0.118673
# 30    0.076351
# 1     0.067203
# 33    0.053665
# 43    0.045249
# 7     0.042444
# 34    0.041834
# 36    0.040249
# 38    0.033663
# 41    0.022198
# 56    0.020246
# 49    0.018051
# 31    0.016465
# 15    0.015368
# 10    0.014026
# 42    0.013416
# 39    0.013050
# 48    0.010977
# 21    0.010123
# 40    0.009879
# 27    0.009757
# 9     0.008050
# 44    0.008050
# 50    0.006464
# 45    0.006098
# 4     0.005610
# 57    0.005367
# 54    0.005245
# 12    0.004757
# 13    0.004391
# 29    0.004025
# 24    0.003781
# 28    0.003537
# 20    0.002683
# 23    0.002439
# 16    0.001951
# 52    0.001951
# 47    0.001708
# 55    0.001342
# 5     0.001342
# 17    0.001342
# 51    0.001342
# 32    0.001220
# 3     0.001220
# 35    0.001220
# 8     0.001098
# 58    0.000854
# 11    0.000854
# 26    0.000488
# 53    0.000488
# 6     0.000366
# 14    0.000366
# 22    0.000366
# 25    0.000244
# 18    0.000244
# 46    0.000122
# ...

# %%
d1_sub = d1[poststrat_vars + ['Q12']]
d1_sub.head()
# Out:
#    AGE  CNTY  pid3 SEX Q42 Q43_1 Q43_2 Q43_3 Q43_4 Q43_5 Q43_6 Q43_7 Q49  Q52  \
# 0   21    20     1   2   6   NaN     1   NaN   NaN   NaN   NaN   NaN   1    1
# 1   33     7     2   2   7     1   NaN   NaN   NaN   NaN   NaN   NaN   1    1
# 2   34    54     1   1   7     1   NaN   NaN   NaN   NaN   NaN   NaN   1    1
# 3   22    15     4   2   3     1   NaN   NaN   NaN   NaN   NaN   NaN   1    2
# 4   26    30     1   1   8     1   NaN   NaN   NaN   NaN   NaN   NaN   1  NaN
#
#   Q53 Q54x Q55  region Q12
# 0   5    3   2       4   1
# 1   1    1   7       1   0
# 2   5    3   4       4   0
# 3   1    2   1       4   1
# 4   5    2   4       8   0

# %%
d1_sub.shape
# Out:
# (8199, 19)

# %%
d1_sub['Q12'] = d1_sub['Q12'].fillna('5')
d1_sub = d1_sub[d1_sub['Q12'] != '5']

# %%
d1_sub[['Q43_1', 'Q43_2', 'Q43_3', 'Q43_4', 'Q43_5', 'Q43_6',
       'Q43_7']] = d1_sub[['Q43_1', 'Q43_2', 'Q43_3', 'Q43_4', 'Q43_5', 'Q43_6',
       'Q43_7']].fillna(0)
d1_sub.head()
# Out:
#    AGE  CNTY  pid3 SEX Q42 Q43_1 Q43_2 Q43_3 Q43_4 Q43_5 Q43_6 Q43_7 Q49  Q52  \
# 0   21    20     1   2   6     0     1     0     0     0     0     0   1    1
# 1   33     7     2   2   7     1     0     0     0     0     0     0   1    1
# 2   34    54     1   1   7     1     0     0     0     0     0     0   1    1
# 3   22    15     4   2   3     1     0     0     0     0     0     0   1    2
# 4   26    30     1   1   8     1     0     0     0     0     0     0   1  NaN
#
#   Q53 Q54x Q55  region Q12
# 0   5    3   2       4   1
# 1   1    1   7       1   0
# 2   5    3   4       4   0
# 3   1    2   1       4   1
# 4   5    2   4       8   0

# %%
race_cols = [k for k in poststrat_vars if k.startswith('Q43')]
race_cols
# Out:
# ['Q43_1', 'Q43_2', 'Q43_3', 'Q43_4', 'Q43_5', 'Q43_6', 'Q43_7']

# %%
for col in race_cols:
    d1_sub[col] = d1_sub[col].astype(int)

# %%
d1_sub['num_race_id'] = np.sum(d1_sub[race_cols], axis=1).astype(int)
d1_sub['num_race_id'].value_counts()
# Out:
# num_race_id
# 1    7197
# 2     560
# 0     182
# 3      58
# 4      10
# 6       2
# 5       2
# Name: count, dtype: int64

# %%
d1_sub.iloc[0, :]
# Out:
# AGE            21
# CNTY           20
# pid3            1
# SEX             2
# Q42             6
# Q43_1           0
# Q43_2           1
# Q43_3           0
# Q43_4           0
# Q43_5           0
# Q43_6           0
# Q43_7           0
# Q49             1
# Q52             1
# Q53             5
# Q54x            3
# Q55             2
# region          4
# Q12             1
# num_race_id     1
# Name: 0, dtype: object

# %%
race = np.full(d1_sub.shape[0], fill_value="placeholder")


for i in tqdm(range(d1_sub.shape[0])):
    row = d1_sub.iloc[i, :]
    if row['num_race_id'] > 1:
        race[i] = 'mixed'
    elif row['num_race_id'] == 0:
        race[i] = 'unknown'
    else:
        if row['Q43_1']:
            race[i] = 'white'
        elif row['Q43_2']:
            race[i] = 'hispanic'
        elif row['Q43_3']:
            race[i] = 'aapi'
        elif row['Q43_4']:
            race[i] = 'black'
        elif row['Q43_5'] or row['Q43_6']:
            race[i] = 'natam' # Native American and Alaska Natives
        else:
            race[i] = 'other'
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████| 8011/8011 [00:00<00:00, 8395.34it/s]

# %%
np.unique(race)
# Out:
# array(['aapi', 'black', 'hispanic', 'mixed', 'natam', 'other', 'unknown',
#        'white'], dtype='<U11')

# %%
d1_sub['race'] = race

# %%
d1_sub['race'].shape
# Out:
# (8011,)

# %%
d1_sub['race'].value_counts(normalize=True)
# Out:
# race
# white       0.586943
# hispanic    0.155037
# aapi        0.089377
# mixed       0.078892
# black       0.054550
# unknown     0.022719
# other       0.007739
# natam       0.004743
# Name: proportion, dtype: float64

# %%
code_race = {
    'white': 0,
    'black': 1,
    'aapi': 2,
    'hispanic': 3,
    'no_answer': 4,
    'other': 5,
    'natam': 6,
    'mixed': 7
}

d1_sub['race'] = d1_sub['race'].replace(code_race)

# %%
d1_sub['race']
# Out:
# 0       3
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 8191    3
# 8193    3
# 8194    3
# 8197    3
# 8198    3
# Name: race, Length: 8011, dtype: object

# %%
## 1: 18-29, 2: 30-39, 3: 40-49, 4: 50-59, 5: 60-60, 6: 70+
d1_sub['AGE'] = d1_sub['AGE'].map(lambda x: 1 if x < 30 else
                                 (2 if x < 40 else (
                                 3 if x < 50 else (
                                 4 if x < 60 else (
                                 5 if x < 70 else 6)))))

# %%
d1_sub['AGE'].value_counts()
# Out:
# AGE
# 2    1565
# 1    1411
# 5    1369
# 3    1279
# 6    1227
# 4    1160
# Name: count, dtype: int64

# %%
d1_sub['Q52'].value_counts()
# Out:
# Q52
# 1    4507
# 2    1775
# 3     460
# Name: count, dtype: int64

# %%
d1_sub['Q52'] = d1_sub['Q52'].replace({
    3: 0
}).fillna(0)

# %%
d1_sub = d1_sub.drop(race_cols + ['num_race_id'], axis='columns')

# %%
d1_sub.head()
# Out:
#    AGE  CNTY  pid3 SEX Q42 Q49 Q52 Q53 Q54x Q55  region Q12 race
# 0    1    20     1   2   6   1   1   5    3   2       4   1    3
# 1    2     7     2   2   7   1   1   1    1   7       1   0    0
# 2    2    54     1   1   7   1   1   5    3   4       4   0    0
# 3    1    15     4   2   3   1   2   1    2   1       4   1    0
# 4    1    30     1   1   8   1   0   5    2   4       8   0    0

# %%
## Education
## 1: Less than high school grad, 2: High school grad,
## 3: Some college, 4: College grad
d1_sub['Q42'] = d1_sub['Q42'].map(
    lambda x: 1 if x in [1, 2] else (
    2 if x == 3 else (
    3 if x in [4, 5, 6] else 4))
)

# %%
d1_sub = d1_sub.drop([
    'pid3', 'Q49', 'Q53', 'Q54x', 'Q55'
], axis='columns')

# %%
d1_sub = d1_sub.fillna(0)

# %%
d1_sub.head()
# Out:
#    AGE  CNTY SEX  Q42 Q52  region  Q12 race
# 0    1    20   2    4   1       4    1    3
# 1    2     7   2    4   1       1    0    0
# 2    2    54   1    4   1       4    0    0
# 3    1    15   2    4   2       4    1    0
# 4    1    30   1    4   0       8    0    0

# %%
demo = pd.read_csv('county_pop_census.csv')
demo.head()
# Out:
#                                   Label (Grouping) Alameda County, California  \
# 0                                           Total:                  1,338,388
# 1                          Population of one race:                  1,208,791
# 2                                      White alone                    448,581
# 3                  Black or African American alone                    134,525
# 4          American Indian and Alaska Native alone                     14,919
#
#   Alpine County, California Amador County, California  \
# 0                     1,009                    34,042
# 1                       941                    31,277
# 2                       736                    26,465
# 3                         9                     1,193
# 4                       174                       578
#
#   Butte County, California Calaveras County, California  \
# 0                  168,339                       37,337
# ...

# %%
demo = demo.T
demo.columns = demo.iloc[0, :]
demo = demo[1:].reset_index()

# %%
# pat = re.compile(r'[A-Za-z, ]+\!\!Estimate$')
# index_filt = np.array([d for d in demo['index'].values if pat.match(d)])
# demo = demo[demo['index'].isin(index_filt)]

# %%
# demo['index'] = demo['index'].str.rstrip(r'Estimate')
# demo['index'] = demo['index'].str.rstrip(r'!!')

# %%
demo.columns = demo.columns.str.lower().str.replace(' ', '_').str.replace(r'[^a-zA-z0-9\(\)]', '').str.replace('\xa0', '')

# %%
demo = demo[['index', 'total:']].rename({
    'index': 'county', 'total:': 'vap'
}, axis=1).reset_index()

# %%
demo.head()
# Out:
# Label (Grouping)  index                        county        vap
# 0                     0    Alameda County, California  1,338,388
# 1                     1     Alpine County, California      1,009
# 2                     2     Amador County, California     34,042
# 3                     3      Butte County, California    168,339
# 4                     4  Calaveras County, California     37,337

# %%
demo['vap'] = demo['vap'].str.rstrip(r'\%').str.replace(',', '').astype(float)

# %%
demo['county'] = demo['county'].str.rstrip(r', California').map(lambda x: x.upper())

# %%
demo.head()
# Out:
# Label (Grouping)  index            county        vap
# 0                     0    ALAMEDA COUNTY  1338388.0
# 1                     1     ALPINE COUNTY     1009.0
# 2                     2     AMADOR COUNTY    34042.0
# 3                     3      BUTTE COUNTY   168339.0
# 4                     4  CALAVERAS COUNTY    37337.0

# %%
pres_res = pd.read_csv('countypres_2000-2024.csv')
pres_res.head()
# Out:
#    year    state state_po county_name  county_fips        office  \
# 0  2000  ALABAMA       AL     AUTAUGA       1001.0  US PRESIDENT
# 1  2000  ALABAMA       AL     AUTAUGA       1001.0  US PRESIDENT
# 2  2000  ALABAMA       AL     AUTAUGA       1001.0  US PRESIDENT
# 3  2000  ALABAMA       AL     AUTAUGA       1001.0  US PRESIDENT
# 4  2000  ALABAMA       AL     BALDWIN       1003.0  US PRESIDENT
#
#         candidate       party  candidatevotes  totalvotes   version   mode
# 0         AL GORE    DEMOCRAT            4942       17208  20250821  TOTAL
# 1  GEORGE W. BUSH  REPUBLICAN           11993       17208  20250821  TOTAL
# 2           OTHER       OTHER             113       17208  20250821  TOTAL
# 3     RALPH NADER       GREEN             160       17208  20250821  TOTAL
# 4         AL GORE    DEMOCRAT           13997       56480  20250821  TOTAL

# %%
pres_res = pres_res[
    (pres_res['year'] == 2020) & (pres_res['state_po'] == 'CA') & (pres_res['party'] == 'DEMOCRAT')
]

# %%
pres_res['county_full'] = pres_res['county_name'] + ' COUNTY'

# %%
pres_res.head()
# Out:
#        year       state state_po county_name  county_fips        office  \
# 52657  2020  CALIFORNIA       CA     ALAMEDA       6001.0  US PRESIDENT
# 52662  2020  CALIFORNIA       CA      ALPINE       6003.0  US PRESIDENT
# 52667  2020  CALIFORNIA       CA      AMADOR       6005.0  US PRESIDENT
# 52672  2020  CALIFORNIA       CA       BUTTE       6007.0  US PRESIDENT
# 52677  2020  CALIFORNIA       CA   CALAVERAS       6009.0  US PRESIDENT
#
#                candidate     party  candidatevotes  totalvotes   version  \
# 52657  JOSEPH R BIDEN JR  DEMOCRAT          617659      770070  20250821
# 52662  JOSEPH R BIDEN JR  DEMOCRAT             476         741  20250821
# 52667  JOSEPH R BIDEN JR  DEMOCRAT            8153       22304  20250821
# 52672  JOSEPH R BIDEN JR  DEMOCRAT           50426      102066  20250821
# 52677  JOSEPH R BIDEN JR  DEMOCRAT           10046       27164  20250821
#
#         mode       county_full
# 52657  TOTAL    ALAMEDA COUNTY
# ...

# %%
pres_res = pd.merge(left=pres_res, right=demo, left_on='county_full', right_on='county', how='left')
pres_res.head()
# Out:
#    year       state state_po county_name  county_fips        office  \
# 0  2020  CALIFORNIA       CA     ALAMEDA       6001.0  US PRESIDENT
# 1  2020  CALIFORNIA       CA      ALPINE       6003.0  US PRESIDENT
# 2  2020  CALIFORNIA       CA      AMADOR       6005.0  US PRESIDENT
# 3  2020  CALIFORNIA       CA       BUTTE       6007.0  US PRESIDENT
# 4  2020  CALIFORNIA       CA   CALAVERAS       6009.0  US PRESIDENT
#
#            candidate     party  candidatevotes  totalvotes   version   mode  \
# 0  JOSEPH R BIDEN JR  DEMOCRAT          617659      770070  20250821  TOTAL
# 1  JOSEPH R BIDEN JR  DEMOCRAT             476         741  20250821  TOTAL
# 2  JOSEPH R BIDEN JR  DEMOCRAT            8153       22304  20250821  TOTAL
# 3  JOSEPH R BIDEN JR  DEMOCRAT           50426      102066  20250821  TOTAL
# 4  JOSEPH R BIDEN JR  DEMOCRAT           10046       27164  20250821  TOTAL
#
#         county_full  index            county        vap
# ...

# %%
pres_res['biden_vote_pct'] = pres_res['candidatevotes'] / pres_res['vap']
# pres_res = pres_res.reset_index().reset_index()
pres_res.head()
# Out:
#    year       state state_po county_name  county_fips        office  \
# 0  2020  CALIFORNIA       CA     ALAMEDA       6001.0  US PRESIDENT
# 1  2020  CALIFORNIA       CA      ALPINE       6003.0  US PRESIDENT
# 2  2020  CALIFORNIA       CA      AMADOR       6005.0  US PRESIDENT
# 3  2020  CALIFORNIA       CA       BUTTE       6007.0  US PRESIDENT
# 4  2020  CALIFORNIA       CA   CALAVERAS       6009.0  US PRESIDENT
#
#            candidate     party  candidatevotes  totalvotes   version   mode  \
# 0  JOSEPH R BIDEN JR  DEMOCRAT          617659      770070  20250821  TOTAL
# 1  JOSEPH R BIDEN JR  DEMOCRAT             476         741  20250821  TOTAL
# 2  JOSEPH R BIDEN JR  DEMOCRAT            8153       22304  20250821  TOTAL
# 3  JOSEPH R BIDEN JR  DEMOCRAT           50426      102066  20250821  TOTAL
# 4  JOSEPH R BIDEN JR  DEMOCRAT           10046       27164  20250821  TOTAL
#
#         county_full  index            county        vap  biden_vote_pct
# ...

# %%
pres_res = pres_res.rename({
    'index': 'level_0'
}, axis='columns')

# %%
pres_res['level_0'] = pres_res['level_0'] + 1

# %%
pres_res['countyicp'] = '71' + pres_res['county_fips'].astype(int).astype(str).str.extract(r'\d(\d+)')

# %%
pres_res.head()
# Out:
#    year       state state_po county_name  county_fips        office  \
# 0  2020  CALIFORNIA       CA     ALAMEDA       6001.0  US PRESIDENT
# 1  2020  CALIFORNIA       CA      ALPINE       6003.0  US PRESIDENT
# 2  2020  CALIFORNIA       CA      AMADOR       6005.0  US PRESIDENT
# 3  2020  CALIFORNIA       CA       BUTTE       6007.0  US PRESIDENT
# 4  2020  CALIFORNIA       CA   CALAVERAS       6009.0  US PRESIDENT
#
#            candidate     party  candidatevotes  totalvotes   version   mode  \
# 0  JOSEPH R BIDEN JR  DEMOCRAT          617659      770070  20250821  TOTAL
# 1  JOSEPH R BIDEN JR  DEMOCRAT             476         741  20250821  TOTAL
# 2  JOSEPH R BIDEN JR  DEMOCRAT            8153       22304  20250821  TOTAL
# 3  JOSEPH R BIDEN JR  DEMOCRAT           50426      102066  20250821  TOTAL
# 4  JOSEPH R BIDEN JR  DEMOCRAT           10046       27164  20250821  TOTAL
#
#         county_full  level_0            county        vap  biden_vote_pct  \
# ...

# %%
pres_res.to_csv('ca_pres_res.csv')

# %%
d1_sub = pd.merge(left=d1_sub, right=pres_res[['level_0', 'biden_vote_pct']], left_on='CNTY', right_on='level_0', how='left')
d1_sub.head()
# Out:
#    AGE  CNTY SEX  Q42 Q52  region  Q12 race  level_0  biden_vote_pct
# 0    1    20   2    4   1       4    1    3       20        0.204612
# 1    2     7   2    4   1       1    0    0        7        0.461282
# 2    2    54   1    4   1       4    0    0       54        0.199657
# 3    1    15   2    4   2       4    1    0       15        0.204631
# 4    1    30   1    4   0       8    0    0       30        0.323063

# %%
d1_sub = d1_sub.drop(['level_0'], axis='columns')

# %%
d1_sub = d1_sub.rename({
    'Q42': 'edu',
    'Q52': '2020_vote'
}, axis=1)

# %%
d1_sub.shape
# Out:
# (8011, 9)

# %%
d1_sub['Q12']
# Out:
# 0       1
# 1       0
# 2       0
# 3       1
# 4       0
#        ..
# 8006    0
# 8007    1
# 8008    1
# 8009    0
# 8010    1
# Name: Q12, Length: 8011, dtype: int64

# %%
d1_sub.head()
# Out:
#    AGE  CNTY SEX  edu 2020_vote  region  Q12 race  biden_vote_pct
# 0    1    20   2    4         1       4    1    3        0.204612
# 1    2     7   2    4         1       1    0    0        0.461282
# 2    2    54   1    4         1       4    0    0        0.199657
# 3    1    15   2    4         2       4    1    0        0.204631
# 4    1    30   1    4         0       8    0    0        0.323063

# %%
np.unique(d1_sub['Q12'])
# Out:
# array([0, 1])

# %%
d1_sub.shape
# Out:
# (8011, 9)

# %%
d1['region'].value_counts()
# Out:
# region
# 1    2078
# 6    1775
# 9     973
# 5     806
# 3     728
# 8     626
# 4     513
# 2     513
# 7     187
# Name: count, dtype: int64

# %%
region_to_cnty = pd.DataFrame(d1[['region', 'CNTY']].value_counts().fillna(0))
region_to_cnty = region_to_cnty.reset_index()
region_to_cnty
# Out:
#     region  CNTY  count
# 0        6    19   1775
# 1        9    37    973
# 2        8    30    626
# 3        1     1    551
# 4        5    33    440
# 5        1    43    371
# 6        1     7    348
# 7        3    34    343
# 8        5    36    330
# 9        1    38    276
# 10       1    41    182
# 11       2    56    166
# 12       1    49    148
# 13       3    31    135
# 14       4    15    126
# 15       4    10    115
# 16       2    42    110
# 17       4    39    107
# 18       1    48     90
# 19       1    21     83
# 20       2    40     81
# 21       2    27     80
# 22       2    44     66
# 23       3     9     66
# 24       4    50     53
# 25       3    45     50
# 26       3     4     46
# 27       3    57     44
# 28       4    54     43
# 29       7    12     39
# 30       5    13     36
# 31       7    29     33
# 32       4    24     31
# 33       1    28     29
# 34       4    20     22
# 35       7    23     20
# 36       4    16     16
# ...

# %%
region_to_cnty['CNTY'].value_counts()
# Out:
# CNTY
# 19    1
# 37    1
# 30    1
# 1     1
# 33    1
# 43    1
# 7     1
# 34    1
# 36    1
# 38    1
# 41    1
# 56    1
# 49    1
# 31    1
# 15    1
# 10    1
# 42    1
# 39    1
# 48    1
# 21    1
# 40    1
# 27    1
# 44    1
# 9     1
# 50    1
# 45    1
# 4     1
# 57    1
# 54    1
# 12    1
# 13    1
# 29    1
# 24    1
# 28    1
# 20    1
# 23    1
# 16    1
# 52    1
# 47    1
# 17    1
# 51    1
# 55    1
# 5     1
# 35    1
# 32    1
# 3     1
# 8     1
# 58    1
# 11    1
# 53    1
# 26    1
# 6     1
# 22    1
# 14    1
# 18    1
# 25    1
# 46    1
# Name: count, dtype: int64

# %%
region_to_cnty.to_csv('region_to_cnty.csv')

# %%
cnty_num_key = pres_res[['county_name', 'level_0']]
cnty_num_key = cnty_num_key.rename({'level_0': 'cnty'}, axis=1)
cnty_num_key.head()
# Out:
#   county_name  cnty
# 0     ALAMEDA     1
# 1      ALPINE     2
# 2      AMADOR     3
# 3       BUTTE     4
# 4   CALAVERAS     5

# %%
cnty_num_key.to_csv('cnty_num_key.csv')

# %%
## Change name of CSV if measuring for other questions!
d1_sub.to_csv('reg_dfs/reg_df_Q12.csv')
